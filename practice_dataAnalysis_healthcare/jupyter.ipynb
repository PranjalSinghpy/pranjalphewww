# %% [markdown]
# # Using Jupyter Notebooks
# :label:`sec_jupyter`
#
#
# This section describes how to edit and run the code
# in each section of this book
# using the Jupyter Notebook. Make sure you have
# installed Jupyter and downloaded the
# code as described in
# :ref:`chap_installation`.
# If you want to know more about Jupyter see the excellent tutorial in
# their [documentation](https://jupyter.readthedocs.io/en/latest/).
#
#
# ## Editing and Running the Code Locally
#
# Suppose that the local path of the book's code is `xx/yy/d2l-en/`. Use the shell to change the directory to this path (`cd xx/yy/d2l-en`) and run the command `jupyter notebook`. If your browser does not do this automatically, open http://localhost:8888 and you will see the interface of Jupyter and all the folders containing the code of the book, as shown in :numref:`fig_jupyter00`.
#
# ![The folders containing the code of this book.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter00.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter00`
#
#
# You can access the notebook files by clicking on the folder displayed on the webpage.
# They usually have the suffix ".ipynb".
# For the sake of brevity, we create a temporary "test.ipynb" file.
# The content displayed after you click it is
# shown in :numref:`fig_jupyter01`.
# This notebook includes a markdown cell and a code cell. The content in the markdown cell includes "This Is a Title" and "This is text.".
# The code cell contains two lines of Python code.
#
# ![Markdown and code cells in the "text.ipynb" file.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter01.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter01`
#
#
# Double click on the markdown cell to enter edit mode.
# Add a new text string "Hello world." at the end of the cell, as shown in :numref:`fig_jupyter02`.
#
# ![Edit the markdown cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter02.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter02`
#
#
# As demonstrated in :numref:`fig_jupyter03`,
# click "Cell" $\rightarrow$ "Run Cells" in the menu bar to run the edited cell.
#
# ![Run the cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter03.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter03`
#
# After running, the markdown cell is shown in :numref:`fig_jupyter04`.
#
# ![The markdown cell after running.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter04.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter04`
#
#
# Next, click on the code cell. Multiply the elements by 2 after the last line of code, as shown in :numref:`fig_jupyter05`.
#
# ![Edit the code cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter05.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter05`
#
#
# You can also run the cell with a shortcut ("Ctrl + Enter" by default) and obtain the output result from :numref:`fig_jupyter06`.
#
# ![Run the code cell to obtain the output.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter06.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter06`
#
#
# When a notebook contains more cells, we can click "Kernel" $\rightarrow$ "Restart & Run All" in the menu bar to run all the cells in the entire notebook. By clicking "Help" $\rightarrow$ "Edit Keyboard Shortcuts" in the menu bar, you can edit the shortcuts according to your preferences.
#
# ## Advanced Options
#
# Beyond local editing two things are quite important: editing the notebooks in the markdown format and running Jupyter remotely.
# The latter matters when we want to run the code on a faster server.
# The former matters since Jupyter's native ipynb format stores a lot of auxiliary data that is
# irrelevant to the content,
# mostly related to how and where the code is run.
# This is confusing for Git, making
# reviewing contributions very difficult.
# Fortunately there is an alternative---native editing in the markdown format.
#
# ### Markdown Files in Jupyter
#
# If you wish to contribute to the content of this book, you need to modify the
# source file (md file, not ipynb file) on GitHub.
# Using the notedown plugin we
# can modify notebooks in the md format directly in Jupyter.
#
#
# First, install the notedown plugin, run the Jupyter Notebook, and load the plugin:
#
# ```
# pip install d2l-notedown  # You may need to uninstall the original notedown.
# jupyter notebook --NotebookApp.contents_manager_class='notedown.NotedownContentsManager'
# ```
#
# You may also turn on the notedown plugin by default whenever you run the Jupyter Notebook.
# First, generate a Jupyter Notebook configuration file (if it has already been generated, you can skip this step).
#
# ```
# jupyter notebook --generate-config
# ```
#
# Then, add the following line to the end of the Jupyter Notebook configuration file (for Linux or macOS, usually in the path `~/.jupyter/jupyter_notebook_config.py`):
#
# ```
# c.NotebookApp.contents_manager_class = 'notedown.NotedownContentsManager'
# ```
#
# After that, you only need to run the `jupyter notebook` command to turn on the notedown plugin by default.
#
# ### Running Jupyter Notebooks on a Remote Server
#
# Sometimes, you may want to run Jupyter notebooks on a remote server and access it through a browser on your local computer. If Linux or macOS is installed on your local machine (Windows can also support this function through third-party software such as PuTTY), you can use port forwarding:
#
# ```
# ssh myserver -L 8888:localhost:8888
# ```
#
# The above string `myserver` is the address of the remote server.
# Then we can use http://localhost:8888 to access the remote server `myserver` that runs Jupyter notebooks. We will detail on how to run Jupyter notebooks on AWS instances
# later in this appendix.
#
# ### Timing
#
# We can use the `ExecuteTime` plugin to time the execution of each code cell in Jupyter notebooks.
# Use the following commands to install the plugin:
#
# ```
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# jupyter nbextension enable execute_time/ExecuteTime
# ```
#
# ## Summary
#
# * Using the Jupyter Notebook tool, we can edit, run, and contribute to each section of the book.
# * We can run Jupyter notebooks on remote servers using port forwarding.
#
#
# ## Exercises
#
# 1. Edit and run the code in this book with the Jupyter Notebook on your local machine.
# 1. Edit and run the code in this book with the Jupyter Notebook *remotely* via port forwarding.
# 1. Compare the running time of the operations $\mathbf{A}^\top \mathbf{B}$ and $\mathbf{A} \mathbf{B}$ for two square matrices in $\mathbb{R}^{1024 \times 1024}$. Which one is faster?
#
#
# [Discussions](https://discuss.d2l.ai/t/421)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("prasad22/healthcare-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'healthcare-dataset' dataset.
# Path to dataset files: /kaggle/input/healthcare-dataset

# %%
import pandas as pd

# %%
import os

# Construct the full path to the CSV file
csv_file_path = os.path.join(path, "healthcare_dataset.csv")

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
display(df.head())
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
import os

# List files in the downloaded directory to find the CSV file
file_list = os.listdir(path)
print("Files in the dataset directory:", file_list)
# Out:
# Files in the dataset directory: ['healthcare_dataset.csv']

# %%
df.sample(5)
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 23623     rOBert baKER   52  Female         B+            Asthma
# 33888     SarAh goLdEn   69    Male         O+          Diabetes
# 1097      JasmInE luNA   27    Male         A-           Obesity
# 23603  Sheena cAstILLo   85    Male         O-           Obesity
# 41240  GreGoRy Ramirez   50  Female        AB+            Asthma
#
#       Date of Admission                Doctor         Hospital  \
# 23623        2023-07-29     Kimberly Mcdonald       Cook Group
# 33888        2021-02-18      Kimberly Schmitt        Wiley LLC
# 1097         2020-04-10  Dr. William Santiago     Horton-Boone
# 23603        2020-03-20        Debbie Johnson  Gentry and Sons
# 41240        2021-06-26         Jackie Garcia      Smith-Henry
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 23623           Medicare    43893.268434          223       Elective
# 33888              Aetna    13405.333426          302         Urgent
# 1097               Cigna    11023.287474          142         Urgent
# 23603           Medicare     6164.706766          316      Emergency
# 41240   UnitedHealthcare    17688.485633          114      Emergency
#
#       Discharge Date   Medication  Test Results
# 23623     2023-08-05    Ibuprofen  Inconclusive
# 33888     2021-02-25      Aspirin      Abnormal
# 1097      2020-05-10  Paracetamol      Abnormal
# 23603     2020-04-13      Lipitor  Inconclusive
# 41240     2021-07-19      Lipitor  Inconclusive

# %%
df.shape
# Out:
# (55500, 15)

# %%
num_rows=df.shape[0]
num_cols=df.shape[1]
print("Number of rows and column:", num_rows, num_cols)
# Out:
# Number of rows and column: 55500 15

# %%
df[["Medical Condition"]]
# Out:
#       Medical Condition
# 0                Cancer
# 1               Obesity
# 2               Obesity
# 3              Diabetes
# 4                Cancer
# ...                 ...
# 55495            Asthma
# 55496           Obesity
# 55497      Hypertension
# 55498         Arthritis
# 55499         Arthritis
#
# [55500 rows x 1 columns]

# %%
selected_columns=df[["Age","Gender","Medical Condition"]]
selected_columns
# Out:
#        Age  Gender Medical Condition
# 0       30    Male            Cancer
# 1       62    Male           Obesity
# 2       76  Female           Obesity
# 3       28  Female          Diabetes
# 4       43  Female            Cancer
# ...    ...     ...               ...
# 55495   42  Female            Asthma
# 55496   61  Female           Obesity
# 55497   38  Female      Hypertension
# 55498   43    Male         Arthritis
# 55499   53  Female         Arthritis
#
# [55500 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# selected_columns['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# selected_columns.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# selected_columns.groupby('Medical Condition').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# selected_columns['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Medical Condition'].value_counts()
#     for x_label, grp in selected_columns.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Medical Condition')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(selected_columns['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(selected_columns, x='Age', y='Gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(selected_columns['Medical Condition'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(selected_columns, x='Age', y='Medical Condition', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
filtered_df =df[df["Medical Condition"]=="Cancer"]
filtered_df
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 0           Bobby JacksOn   30    Male         B-            Cancer
# 4           adrIENNE bEll   43  Female        AB+            Cancer
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# 9        ChRISTopher BerG   58  Female        AB-            Cancer
# 10       mIchElLe daniELs   72    Male         O+            Cancer
# ...                   ...  ...     ...        ...               ...
# 55448      tIFfANy miller   78    Male         B-            Cancer
# 55456        DEBRa MIller   17    Male        AB-            Cancer
# 55479    mIcHAeL SanTiAgo   58  Female         B-            Cancer
# 55484     keNNEtH alvarez   80    Male         O+            Cancer
# 55490    STepHAniE oliVer   82    Male         B-            Cancer
#
#       Date of Admission            Doctor                     Hospital  \
# 0            2024-01-31     Matthew Smith              Sons and Miller
# 4            2022-09-19    Kathleen Hanna                  White-White
# 7            2021-12-28    Suzanne Thomas  Powell Robinson and Valdez,
# 9            2021-05-23       Heather Day               Padilla-Walker
# 10           2020-04-19       John Duncan              Schaefer-Porter
# ...                 ...               ...                          ...
# 55448        2023-06-22      Jaime Valdez            Sons Williams and
# 55456        2021-07-29  Samantha Russell               Collier-Jordan
# 55479        2022-01-05     Andrea Fields                 Berry-Nguyen
# 55484        2022-05-05     Andrew Conner                Sons Mayo and
# 55490        2022-01-10      Gary Leblanc                    Group Lee
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0             Blue Cross    18856.281306          328         Urgent
# 4                  Aetna    14238.317814          458         Urgent
# 7                  Cigna    45820.462722          277      Emergency
# 9       UnitedHealthcare    19784.631062          249       Elective
# 10              Medicare    12576.795609          394         Urgent
# ...                  ...             ...          ...            ...
# 55448   UnitedHealthcare    17217.325440          287         Urgent
# 55456   UnitedHealthcare    43230.028453          125         Urgent
# 55479           Medicare    45767.175201          299       Elective
# 55484              Cigna    45653.802310          114       Elective
# 55490              Cigna    17350.543524          381      Emergency
#
#       Discharge Date   Medication  Test Results
# 0         2024-02-02  Paracetamol        Normal
# 4         2022-10-09   Penicillin      Abnormal
# 7         2022-01-07  Paracetamol  Inconclusive
# 9         2021-06-22  Paracetamol  Inconclusive
# 10        2020-04-22  Paracetamol        Normal
# ...              ...          ...           ...
# 55448     2023-06-30    Ibuprofen  Inconclusive
# 55456     2021-08-01    Ibuprofen      Abnormal
# 55479     2022-01-29    Ibuprofen        Normal
# 55484     2022-05-17      Aspirin        Normal
# 55490     2022-01-21   Penicillin      Abnormal
#
# [9227 rows x 15 columns]

# %%
filter_df=df[(df['Age']<=20) & (df["Medical Condition"]=="Cancer")]
filter_df
# Out:
#                        Name  Age  Gender Blood Type Medical Condition  \
# 7        CHrisTInA MARtinez   20  Female         A+            Cancer
# 62            tRAvIs carTeR   18    Male         A+            Cancer
# 121            RENEE bAilEY   19  Female         B+            Cancer
# 123    DR. LaUreN ClaRk DDs   19    Male         B+            Cancer
# 172            rOBert WAlsH   20  Female         B+            Cancer
# ...                     ...  ...     ...        ...               ...
# 55200         RacHEL MOonEy   18    Male         O-            Cancer
# 55250        cheLSeA FrENCh   20    Male         A+            Cancer
# 55270          DeReK holMeS   19    Male         B-            Cancer
# 55406        mEGaN pHiLliPS   19  Female         O-            Cancer
# 55456          DEBRa MIller   17    Male        AB-            Cancer
#
#       Date of Admission               Doctor                     Hospital  \
# 7            2021-12-28       Suzanne Thomas  Powell Robinson and Valdez,
# 62           2022-07-06           Megan Hahn     Moss and Ferguson, Baker
# 121          2021-07-03        Sarah Shaffer     Johnson, and Ross Harris
# 123          2020-10-26         Brian Wagner                  PLC Jimenez
# 172          2020-11-22       Sabrina Rogers  and Anderson Smith Sanchez,
# ...                 ...                  ...                          ...
# 55200        2019-10-04    Jonathan Mcdonald                   Daniel PLC
# 55250        2020-11-10          Rachel Rose               Johnson-Chavez
# 55270        2021-10-07        Jesse Holland                    Ltd Burke
# 55406        2021-02-25  Valerie Christensen            Williams and Sons
# 55456        2021-07-29     Samantha Russell               Collier-Jordan
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 7                  Cigna    45820.462722          277      Emergency
# 62      UnitedHealthcare    48407.386291          325      Emergency
# 121             Medicare    33681.572644          177       Elective
# 123     UnitedHealthcare    49833.707718          302       Elective
# 172                Cigna    40598.422571          113       Elective
# ...                  ...             ...          ...            ...
# 55200         Blue Cross    46262.929016          295       Elective
# 55250   UnitedHealthcare     5877.265250          248      Emergency
# 55270           Medicare    37247.769333          437       Elective
# 55406           Medicare     6896.013990          375      Emergency
# 55456   UnitedHealthcare    43230.028453          125         Urgent
#
#       Discharge Date   Medication  Test Results
# 7         2022-01-07  Paracetamol  Inconclusive
# 62        2022-07-18      Aspirin        Normal
# 121       2021-07-31    Ibuprofen      Abnormal
# 123       2020-11-17      Lipitor  Inconclusive
# 172       2020-12-17  Paracetamol        Normal
# ...              ...          ...           ...
# 55200     2019-10-18  Paracetamol        Normal
# 55250     2020-11-19    Ibuprofen  Inconclusive
# 55270     2021-11-01  Paracetamol      Abnormal
# 55406     2021-03-14   Penicillin      Abnormal
# 55456     2021-08-01    Ibuprofen      Abnormal
#
# [417 rows x 15 columns]

# %%
df_sorted=df.sort_values(by="Age")
df_sorted
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 53528  eLIzABETh cAsTILlO   13    Male        AB-      Hypertension
# 50377      jamES BasS phD   13    Male         O+            Asthma
# 50823       DEaNnA pALMeR   13    Male        AB-           Obesity
# 52172      CHArlEs joRDAN   13    Male         A+         Arthritis
# 51095        cAthY BARNES   13    Male         O-           Obesity
# ...                   ...  ...     ...        ...               ...
# 53825       mIchaeL POtTs   89    Male         A+      Hypertension
# 55385      hEAthEr dawsOn   89    Male         O-         Arthritis
# 52857     THomAs PHIllIpS   89  Female         A+      Hypertension
# 52828        doNALD aViLA   89  Female        AB-            Asthma
# 52043        DAVId NeWTOn   89  Female         O+         Arthritis
#
#       Date of Admission             Doctor                         Hospital  \
# 53528        2021-01-03      Dawn Williams                    Thomas-Pierce
# 50377        2020-12-30   Jennifer Hammond        Pollard Wallace, Sims and
# 50823        2020-09-20     Barbara Butler      and Sanchez Phillips, Brown
# 52172        2021-05-13        Brian Baker  Arellano and Armstrong Hensley,
# 51095        2023-03-30      Kevin Ellison                     Wood-Johnson
# ...                 ...                ...                              ...
# 53825        2023-01-19        Mary Vaughn      and Perez, Bennett Townsend
# 55385        2022-07-18           Ann Hall                       Moore-Gray
# 52857        2022-05-22         Mark White         and Martin, Davidson Cox
# 52828        2022-09-17  Christopher Allen        Holmes and Howard Castro,
# 52043        2021-02-08      Jerry Hopkins          Cooper Brown Parks, and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 53528              Aetna    32900.044478          176       Elective
# 50377         Blue Cross    22901.022707          476      Emergency
# 50823           Medicare    23941.759486          163      Emergency
# 52172   UnitedHealthcare    10597.383799          451      Emergency
# 51095           Medicare    29170.617795          348      Emergency
# ...                  ...             ...          ...            ...
# 53825              Cigna     9542.739709          289      Emergency
# 55385              Aetna    17172.115995          455       Elective
# 52857              Cigna    48274.348627          332         Urgent
# 52828              Aetna    14042.748908          199      Emergency
# 52043              Aetna    34500.016817          242       Elective
#
#       Discharge Date   Medication  Test Results
# 53528     2021-01-27      Aspirin      Abnormal
# 50377     2021-01-17    Ibuprofen  Inconclusive
# 50823     2020-09-23   Penicillin  Inconclusive
# 52172     2021-06-12   Penicillin        Normal
# 51095     2023-04-29      Lipitor      Abnormal
# ...              ...          ...           ...
# 53825     2023-01-28  Paracetamol      Abnormal
# 55385     2022-08-13    Ibuprofen        Normal
# 52857     2022-05-26   Penicillin  Inconclusive
# 52828     2022-09-27      Aspirin      Abnormal
# 52043     2021-02-20   Penicillin  Inconclusive
#
# [55500 rows x 15 columns]

# %%
df_sorted =df.sort_values(by="Age", ascending=False)
display(df_sorted)
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 54813   JerEmY hArdIN JR.   89    Male         A+          Diabetes
# 54044   MiChAEL DOmINGuEz   89    Male         O+            Cancer
# 53825       mIchaeL POtTs   89    Male         A+      Hypertension
# 52857     THomAs PHIllIpS   89  Female         A+      Hypertension
# 52043        DAVId NeWTOn   89  Female         O+         Arthritis
# ...                   ...  ...     ...        ...               ...
# 50908        rOnalD daVis   13    Male         A+           Obesity
# 50823       DEaNnA pALMeR   13    Male        AB-           Obesity
# 54302         dAWn chAveZ   13    Male        AB+            Cancer
# 53528  eLIzABETh cAsTILlO   13    Male        AB-      Hypertension
# 53590       JessICA CHuNG   13    Male        AB+           Obesity
#
#       Date of Admission          Doctor                     Hospital  \
# 54813        2019-11-05  Willie Stevens                 Gray-Solomon
# 54044        2021-09-07   Bridget Irwin                    PLC White
# 53825        2023-01-19     Mary Vaughn  and Perez, Bennett Townsend
# 52857        2022-05-22      Mark White     and Martin, Davidson Cox
# 52043        2021-02-08   Jerry Hopkins      Cooper Brown Parks, and
# ...                 ...             ...                          ...
# 50908        2023-12-06  Shannon Butler    Kelly, and Gomez Williams
# 50823        2020-09-20  Barbara Butler  and Sanchez Phillips, Brown
# 54302        2023-03-13   David Mcclure     Taylor, Boyle Dalton and
# 53528        2021-01-03   Dawn Williams                Thomas-Pierce
# 53590        2020-07-06    Leah Hancock               Davis-Lawrence
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 54813              Cigna     7242.641277          113       Elective
# 54044              Aetna     7628.951322          363       Elective
# 53825              Cigna     9542.739709          289      Emergency
# 52857              Cigna    48274.348627          332         Urgent
# 52043              Aetna    34500.016817          242       Elective
# ...                  ...             ...          ...            ...
# 50908              Cigna     3014.565852          241      Emergency
# 50823           Medicare    23941.759486          163      Emergency
# 54302   UnitedHealthcare    43935.226905          478      Emergency
# 53528              Aetna    32900.044478          176       Elective
# 53590         Blue Cross    32019.913320          129         Urgent
#
#       Discharge Date   Medication  Test Results
# 54813     2019-11-28   Penicillin        Normal
# 54044     2021-09-24      Aspirin      Abnormal
# 53825     2023-01-28  Paracetamol      Abnormal
# 52857     2022-05-26   Penicillin  Inconclusive
# 52043     2021-02-20   Penicillin  Inconclusive
# ...              ...          ...           ...
# 50908     2024-01-04  Paracetamol        Normal
# 50823     2020-09-23   Penicillin  Inconclusive
# 54302     2023-03-25    Ibuprofen      Abnormal
# 53528     2021-01-27      Aspirin      Abnormal
# 53590     2020-07-11      Aspirin      Abnormal
#
# [55500 rows x 15 columns]

# %%
avg_price = df["Age"].mean()
display(avg_price)
# Out:
# np.float64(51.53945945945946)

# %%
max_age = df["Age"].max()
display(max_age)
# Out:
# 89

# %%
diag_count= df["Medical Condition"].value_counts()
display(diag_count)
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
grouped_df = df.groupby('Medication').agg({'Medication': 'count'})
display(grouped_df)
# Out:
#              Medication
# Medication
# Aspirin           11094
# Ibuprofen         11127
# Lipitor           11140
# Paracetamol       11071
# Penicillin        11068
